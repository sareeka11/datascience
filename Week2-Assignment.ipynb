# %%
import pandas as pd
#df=pd.read_csv()
#df=pd.read_excel()
df=pd.read_excel(r"D:\Workshop\Datascience\Breast-Cancer-Detection-using-Machine-Learning-master\cancer dataset.xlsx")
print(df)
df.head(5)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
#Q1
# independant variable-id,radius_mean,texture_mean,smoothness_worst,compactness_worst,concavity_worst,concave points_worst,
# symmetry_worst,fractal_dimension_worst,radius_se,compactness_se,concavity_se,concave points_se,symmetry_se,smoothness_mean,
# compactness_mean,concavity_mean,concave_points_mean,symmetry_mean,texture_se,fractal_dimension_se

# dependant variable-perimeter_mean,texture_worst,area_mean,radius_worst,perimeter_worst,area_worst,perimeter_se,area_se,
# smoothness_se,fractal_dimension_mean

# %%
#Q2
df.describe
# Out:
# <bound method NDFrame.describe of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
#Q3
df.shape
#(569,32)
# Out:
# (569, 32)

# %%
#Q4
df.isnull()
# Out:
#         id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    False      False        False         False           False      False
# 1    False      False        False         False           False      False
# 2    False      False        False         False           False      False
# 3    False      False        False         False           False      False
# 4    False      False        False         False           False      False
# 5    False      False        False         False           False      False
# 6    False      False        False         False           False      False
# 7    False      False        False         False           False      False
# 8    False      False        False         False           False      False
# 9    False      False        False         False           False      False
# 10   False      False        False         False           False      False
# ...

# %%
#Q5
df.groupby('diagnosis').count()
# Out:
#             id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# diagnosis
# B          357          357           357             357        357
# M          212          212           212             212        212
#
#            smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B                      357               357             357
# M                      212               212             212
#
#            concave points_mean  symmetry_mean           ...             \
# diagnosis                                               ...
# B                          357            357           ...
# M                          212            212           ...
#
#            radius_worst  texture_worst  perimeter_worst  area_worst  \
# diagnosis
# B                   357            357              357         357
# M                   212            212              212         212
#
#            smoothness_worst  compactness_worst  concavity_worst  \
# ...

# %%
#Q6
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
labelencoder_Y=LabelEncoder()
df.iloc[:,1]=labelencoder_Y.fit_transform(df.iloc[:,1].values)
sns.pairplot(df, vars = ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean'])

#Finding-
#1.radius_mean is directly proportional to perimeter mean

# %%
#Q7
import matplotlib.pyplot as plt
# %matplotlib inline
df.corr()

#Strongly corelated quantities--radius_mean,perimeter_mean,area_mean,radius_worst,area_worst,perimeter_worst,radius_se,
#perimeter_se,area_se

#negatively correlated quantitis--radius_mean,perimeter_mean,area_mean,radius_worst,area_worst,perimeter_worst
#with fractal_dimension_mean,smoothness_se

#Weakly correlated quantitites--symmetry_mean,compactness_mean,symmetry_se,texture_se,id,smoothness_mean,fractal_dimension_se,
#smoothness_worst,symmetry_worst,fractal_dimension_worst
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
#Q8
import seaborn as sns
plt.figure(figsize = (20, 15))
sns.heatmap(df.corr(), cmap = 'coolwarm', annot = True)
